# %% [markdown]
# Connected to .venv (Python 3.9.2)

# %% [markdown]
#   ## Modelo de predição Score de crédito

# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dados_usados/lending_club_loan_two.csv")

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# 1     17.0     0.0   20131.0       53.3      27.0                    f
# 2     13.0     0.0   11987.0       92.2      26.0                    f
# 3      6.0     0.0    5472.0       21.5      13.0                    f
# 4     13.0     0.0   24584.0       69.8      43.0                    f
#
#   application_type  mort_acc  pub_rec_bankruptcies  \
# 0       INDIVIDUAL       0.0                   0.0
# 1       INDIVIDUAL       3.0                   0.0
# 2       INDIVIDUAL       0.0                   0.0
# 3       INDIVIDUAL       0.0                   0.0
# 4       INDIVIDUAL       1.0                   0.0
#
#                                              address
# 0     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3            823 Reid Ford\r\nDelacruzside, MA 00813
# 4             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 396025    10000.0   60 months     10.99       217.38     B        B4
# 396026    21000.0   36 months     12.29       700.42     C        C1
# 396027     5000.0   36 months      9.99       161.32     B        B1
# 396028    21000.0   60 months     15.31       503.02     C        C2
# 396029     2000.0   36 months     13.61        67.98     C        C2
#
#                        emp_title emp_length home_ownership  annual_inc  ...  \
# 396025          licensed bankere    2 years           RENT     40000.0  ...
# 396026                     Agent    5 years       MORTGAGE    110000.0  ...
# 396027              City Carrier  10+ years           RENT     56500.0  ...
# 396028      Gracon Services, Inc  10+ years       MORTGAGE     64000.0  ...
# 396029  Internal Revenue Service  10+ years           RENT     42996.0  ...
#
#        open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 396025      6.0     0.0    1990.0       34.3      23.0                    w
# 396026      6.0     0.0   43263.0       95.7       8.0                    f
# 396027     15.0     0.0   32704.0       66.9      23.0                    f
# 396028      9.0     0.0   15704.0       53.8      20.0                    f
# 396029      3.0     0.0    4292.0       91.3      19.0                    f
#
#        application_type  mort_acc  pub_rec_bankruptcies  \
# 396025       INDIVIDUAL       0.0                   0.0
# 396026       INDIVIDUAL       1.0                   0.0
# 396027       INDIVIDUAL       0.0                   0.0
# 396028       INDIVIDUAL       5.0                   0.0
# 396029       INDIVIDUAL       NaN                   0.0
#
#                                                   address
# 396025   12951 Williams Crossing\r\nJohnnyville, DC 30723
# 396026  0114 Fowler Field Suite 028\r\nRachelborough, ...
# 396027  953 Matthew Points Suite 414\r\nReedfort, NY 7...
# 396028  7843 Blake Freeway Apt. 229\r\nNew Michael, FL...
# 396029      787 Michelle Causeway\r\nBriannaton, AR 48052
#
# [5 rows x 27 columns]

# %%
colunas_traducao = {
    "loan_amnt": "valor_do_emprestimo",
    "term": "prazo_do_emprestimo",
    "int_rate": "taxa_de_juros",
    "installment": "valor_da_parcela",
    "grade": "classificacao_de_risco",
    "sub_grade": "sub_classificacao_de_risco",
    "emp_title": "cargo_profissao",
    "emp_length": "tempo_de_emprego",
    "home_ownership": "tipo_de_moradia",
    "annual_inc": "renda_anual",
    "verification_status": "status_de_verificacao_da_renda",
    "issue_d": "data_de_emissao_do_emprestimo",
    "loan_status": "status_do_emprestimo",
    "purpose": "finalidade_do_emprestimo",
    "title": "titulo_descricao_do_emprestimo",
    "dti": "relacao_divida_renda",
    "earliest_cr_line": "primeira_linha_de_credito",
    "open_acc": "contas_de_credito_abertas",
    "pub_rec": "registros_publicos_negativos",
    "revol_bal": "saldo_de_credito_rotativo",
    "revol_util": "utilizacao_do_credito_rotativo",
    "total_acc": "total_de_contas_de_credito",
    "initial_list_status": "status_inicial_de_listagem",
    "application_type": "tipo_de_aplicacao",
    "mort_acc": "contas_de_hipoteca",
    "pub_rec_bankruptcies": "registros_de_falencia",
    "address": "endereco"
}

# %%
df = df.rename(columns = colunas_traducao)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   valor_do_emprestimo             396030 non-null  float64
#  1   prazo_do_emprestimo             396030 non-null  object
#  2   taxa_de_juros                   396030 non-null  float64
#  3   valor_da_parcela                396030 non-null  float64
#  4   classificacao_de_risco          396030 non-null  object
#  5   sub_classificacao_de_risco      396030 non-null  object
#  6   cargo_profissao                 373103 non-null  object
#  7   tempo_de_emprego                377729 non-null  object
#  8   tipo_de_moradia                 396030 non-null  object
#  9   renda_anual                     396030 non-null  float64
#  10  status_de_verificacao_da_renda  396030 non-null  object
#  11  data_de_emissao_do_emprestimo   396030 non-null  object
#  12  status_do_emprestimo            396030 non-null  object
#  13  finalidade_do_emprestimo        396030 non-null  object
#  14  titulo_descricao_do_emprestimo  394274 non-null  object
#  15  relacao_divida_renda            396030 non-null  float64
#  16  primeira_linha_de_credito       396030 non-null  object
#  17  contas_de_credito_abertas       396030 non-null  float64
#  18  registros_publicos_negativos    396030 non-null  float64
#  19  saldo_de_credito_rotativo       396030 non-null  float64
#  20  utilizacao_do_credito_rotativo  395754 non-null  float64
#  21  total_de_contas_de_credito      396030 non-null  float64
#  22  status_inicial_de_listagem      396030 non-null  object
#  23  tipo_de_aplicacao               396030 non-null  object
#  24  contas_de_hipoteca              358235 non-null  float64
#  25  registros_de_falencia           395495 non-null  float64
#  26  endereco                        396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %%
df.isnull().sum()
# Out:
# valor_do_emprestimo                   0
# prazo_do_emprestimo                   0
# taxa_de_juros                         0
# valor_da_parcela                      0
# classificacao_de_risco                0
# sub_classificacao_de_risco            0
# cargo_profissao                   22927
# tempo_de_emprego                  18301
# tipo_de_moradia                       0
# renda_anual                           0
# status_de_verificacao_da_renda        0
# data_de_emissao_do_emprestimo         0
# status_do_emprestimo                  0
# finalidade_do_emprestimo              0
# titulo_descricao_do_emprestimo     1756
# relacao_divida_renda                  0
# primeira_linha_de_credito             0
# contas_de_credito_abertas             0
# registros_publicos_negativos          0
# saldo_de_credito_rotativo             0
# utilizacao_do_credito_rotativo      276
# total_de_contas_de_credito            0
# status_inicial_de_listagem            0
# tipo_de_aplicacao                     0
# contas_de_hipoteca                37795
# registros_de_falencia               535
# endereco                              0
# dtype: int64

# %%
df["contas_de_hipoteca"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 396030 entries, 0 to 396029
# Series name: contas_de_hipoteca
# Non-Null Count   Dtype
# --------------   -----
# 358235 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0 MB

# %%
df["registros_de_falencia"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 396030 entries, 0 to 396029
# Series name: registros_de_falencia
# Non-Null Count   Dtype
# --------------   -----
# 395495 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0 MB

# %%
df["utilizacao_do_credito_rotativo"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 396030 entries, 0 to 396029
# Series name: utilizacao_do_credito_rotativo
# Non-Null Count   Dtype
# --------------   -----
# 395754 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0 MB

# %%
df["utilizacao_do_credito_rotativo"] = df["utilizacao_do_credito_rotativo"].fillna(df["utilizacao_do_credito_rotativo"].median())
df["contas_de_hipoteca"] = df["contas_de_hipoteca"].fillna(df["contas_de_hipoteca"].median())
df["registros_de_falencia"] = df["registros_de_falencia"].fillna(df["registros_de_falencia"].median())

# %%
df.isna().sum()
# Out:
# valor_do_emprestimo                   0
# prazo_do_emprestimo                   0
# taxa_de_juros                         0
# valor_da_parcela                      0
# classificacao_de_risco                0
# sub_classificacao_de_risco            0
# cargo_profissao                   22927
# tempo_de_emprego                  18301
# tipo_de_moradia                       0
# renda_anual                           0
# status_de_verificacao_da_renda        0
# data_de_emissao_do_emprestimo         0
# status_do_emprestimo                  0
# finalidade_do_emprestimo              0
# titulo_descricao_do_emprestimo     1756
# relacao_divida_renda                  0
# primeira_linha_de_credito             0
# contas_de_credito_abertas             0
# registros_publicos_negativos          0
# saldo_de_credito_rotativo             0
# utilizacao_do_credito_rotativo        0
# total_de_contas_de_credito            0
# status_inicial_de_listagem            0
# tipo_de_aplicacao                     0
# contas_de_hipoteca                    0
# registros_de_falencia                 0
# endereco                              0
# dtype: int64

# %%
df["tempo_de_emprego"].value_counts()
# Out:
# tempo_de_emprego
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: count, dtype: int64

# %%
tempo_emprego = {
"10+ years" : 10,
"2 years" : 2,
"< 1 year" : 0,
"3 years" : 3,
"5 years" : 5,
"1 year" : 1, 
"4 years" : 4, 
"6 years" : 6,
"7 years" : 7 , 
"8 years" : 8,
"9 years" : 9
}

# %%
df["tempo_de_emprego"] = df["tempo_de_emprego"].map(tempo_emprego)

# %%
df["tempo_de_emprego"].value_counts()
# Out:
# tempo_de_emprego
# 10.0    126041
# 2.0      35827
# 0.0      31725
# 3.0      31665
# 5.0      26495
# 1.0      25882
# 4.0      23952
# 6.0      20841
# 7.0      20819
# 8.0      19168
# 9.0      15314
# Name: count, dtype: int64

# %%
df["tempo_de_emprego"] = df["tempo_de_emprego"].replace(np.nan, df["tempo_de_emprego"].median())

# %%
df["tempo_de_emprego"].sample(20)
# Out:
# 203072     7.0
# 275685     2.0
# 53795     10.0
# 289547     0.0
# 145535     5.0
# 12516      1.0
# 207642    10.0
# 325725     8.0
# 374861     9.0
# 206556    10.0
# 285012    10.0
# 283264     2.0
# 374261     4.0
# 56643      0.0
# 284480     6.0
# 153728     7.0
# 130136     5.0
# 179516     7.0
# 89667     10.0
# 21978     10.0
# Name: tempo_de_emprego, dtype: float64

# %%
df = df.drop(["titulo_descricao_do_emprestimo", "cargo_profissao", "status_inicial_de_listagem", "status_de_verificacao_da_renda"], axis=1)

# %%
df = df.drop(["classificacao_de_risco", "sub_classificacao_de_risco"], axis=1)

# %%
df.isnull().sum()
# Out:
# valor_do_emprestimo               0
# prazo_do_emprestimo               0
# taxa_de_juros                     0
# valor_da_parcela                  0
# tempo_de_emprego                  0
# tipo_de_moradia                   0
# renda_anual                       0
# data_de_emissao_do_emprestimo     0
# status_do_emprestimo              0
# finalidade_do_emprestimo          0
# relacao_divida_renda              0
# primeira_linha_de_credito         0
# contas_de_credito_abertas         0
# registros_publicos_negativos      0
# saldo_de_credito_rotativo         0
# utilizacao_do_credito_rotativo    0
# total_de_contas_de_credito        0
# tipo_de_aplicacao                 0
# contas_de_hipoteca                0
# registros_de_falencia             0
# endereco                          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   valor_do_emprestimo             396030 non-null  float64
#  1   prazo_do_emprestimo             396030 non-null  object
#  2   taxa_de_juros                   396030 non-null  float64
#  3   valor_da_parcela                396030 non-null  float64
#  4   tempo_de_emprego                396030 non-null  float64
#  5   tipo_de_moradia                 396030 non-null  object
#  6   renda_anual                     396030 non-null  float64
#  7   data_de_emissao_do_emprestimo   396030 non-null  object
#  8   status_do_emprestimo            396030 non-null  object
#  9   finalidade_do_emprestimo        396030 non-null  object
#  10  relacao_divida_renda            396030 non-null  float64
#  11  primeira_linha_de_credito       396030 non-null  object
#  12  contas_de_credito_abertas       396030 non-null  float64
#  13  registros_publicos_negativos    396030 non-null  float64
#  14  saldo_de_credito_rotativo       396030 non-null  float64
#  15  utilizacao_do_credito_rotativo  396030 non-null  float64
#  16  total_de_contas_de_credito      396030 non-null  float64
#  17  tipo_de_aplicacao               396030 non-null  object
#  18  contas_de_hipoteca              396030 non-null  float64
#  19  registros_de_falencia           396030 non-null  float64
#  20  endereco                        396030 non-null  object
# dtypes: float64(13), object(8)
# memory usage: 63.5+ MB

# %%
colunas_numericas = []
colunas_texto = []
for i in df.columns.tolist():
  if df[i].dtype == "int64" or df[i].dtype == "float64":
     colunas_numericas.append(i)
  else:
     colunas_texto.append(i)

# %%
colunas_numericas
# Out:
# ['valor_do_emprestimo',
#  'taxa_de_juros',
#  'valor_da_parcela',
#  'tempo_de_emprego',
#  'renda_anual',
#  'relacao_divida_renda',
#  'contas_de_credito_abertas',
#  'registros_publicos_negativos',
#  'saldo_de_credito_rotativo',
#  'utilizacao_do_credito_rotativo',
#  'total_de_contas_de_credito',
#  'contas_de_hipoteca',
#  'registros_de_falencia']

# %%
colunas_texto
# Out:
# ['prazo_do_emprestimo',
#  'tipo_de_moradia',
#  'data_de_emissao_do_emprestimo',
#  'status_do_emprestimo',
#  'finalidade_do_emprestimo',
#  'primeira_linha_de_credito',
#  'tipo_de_aplicacao',
#  'endereco']

# %%
colunas_codificadas = {}

for i in df.columns:
    if df[i].dtype == "object":
     codificador = LabelEncoder()
     df[i] = codificador.fit_transform(df[i])
     colunas_codificadas[i] = codificador

# %%
colunas_codificadas
# Out:
# {'prazo_do_emprestimo': LabelEncoder(),
#  'tipo_de_moradia': LabelEncoder(),
#  'data_de_emissao_do_emprestimo': LabelEncoder(),
#  'status_do_emprestimo': LabelEncoder(),
#  'finalidade_do_emprestimo': LabelEncoder(),
#  'primeira_linha_de_credito': LabelEncoder(),
#  'tipo_de_aplicacao': LabelEncoder(),
#  'endereco': LabelEncoder()}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   valor_do_emprestimo             396030 non-null  float64
#  1   prazo_do_emprestimo             396030 non-null  int64
#  2   taxa_de_juros                   396030 non-null  float64
#  3   valor_da_parcela                396030 non-null  float64
#  4   tempo_de_emprego                396030 non-null  float64
#  5   tipo_de_moradia                 396030 non-null  int64
#  6   renda_anual                     396030 non-null  float64
#  7   data_de_emissao_do_emprestimo   396030 non-null  int64
#  8   status_do_emprestimo            396030 non-null  int64
#  9   finalidade_do_emprestimo        396030 non-null  int64
#  10  relacao_divida_renda            396030 non-null  float64
#  11  primeira_linha_de_credito       396030 non-null  int64
#  12  contas_de_credito_abertas       396030 non-null  float64
#  13  registros_publicos_negativos    396030 non-null  float64
#  14  saldo_de_credito_rotativo       396030 non-null  float64
#  15  utilizacao_do_credito_rotativo  396030 non-null  float64
#  16  total_de_contas_de_credito      396030 non-null  float64
#  17  tipo_de_aplicacao               396030 non-null  int64
#  18  contas_de_hipoteca              396030 non-null  float64
#  19  registros_de_falencia           396030 non-null  float64
#  20  endereco                        396030 non-null  int64
# dtypes: float64(13), int64(8)
# memory usage: 63.5 MB

# %%
#df.to_csv("dados_para_modelo", sep=",", encoding="utf-8", index=False)

# %%
corr = df.corr()

grafico_calor = plt.figure(figsize=(12, 8))

sns.heatmap(corr, annot=True)

grafico_calor.show
# Out:
# <bound method Figure.show of <Figure size 1200x800 with 2 Axes>>

# %% [markdown]
#    # Modelo de predição Score de crédito

# %% [markdown]
#  # 1_fase: Importando bibliotecas

# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#  # 2_fase: Lendo o DataFrame

# %% [markdown]
#  *Essa parte tem o objetivo de trazer os dados, ver se estão corretos, e ajudar a facilitar a leitura posteriormente*

# %% [markdown]
#  Trazendo o df atravéz do pandas e vendo se veio corretamente

# %%
df = pd.read_csv("dados_usados/lending_club_loan_two.csv")

# %% [markdown]
#  Vendo as 5 primeiras linhas

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# 1     17.0     0.0   20131.0       53.3      27.0                    f
# 2     13.0     0.0   11987.0       92.2      26.0                    f
# 3      6.0     0.0    5472.0       21.5      13.0                    f
# 4     13.0     0.0   24584.0       69.8      43.0                    f
#
#   application_type  mort_acc  pub_rec_bankruptcies  \
# 0       INDIVIDUAL       0.0                   0.0
# 1       INDIVIDUAL       3.0                   0.0
# 2       INDIVIDUAL       0.0                   0.0
# 3       INDIVIDUAL       0.0                   0.0
# 4       INDIVIDUAL       1.0                   0.0
#
#                                              address
# 0     0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1  1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2  87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3            823 Reid Ford\r\nDelacruzside, MA 00813
# 4             679 Luna Roads\r\nGreggshire, VA 11650
#
# [5 rows x 27 columns]

# %% [markdown]
#  Vendo as ultimas 5 linhas

# %%
df.tail()
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 396025    10000.0   60 months     10.99       217.38     B        B4
# 396026    21000.0   36 months     12.29       700.42     C        C1
# 396027     5000.0   36 months      9.99       161.32     B        B1
# 396028    21000.0   60 months     15.31       503.02     C        C2
# 396029     2000.0   36 months     13.61        67.98     C        C2
#
#                        emp_title emp_length home_ownership  annual_inc  ...  \
# 396025          licensed bankere    2 years           RENT     40000.0  ...
# 396026                     Agent    5 years       MORTGAGE    110000.0  ...
# 396027              City Carrier  10+ years           RENT     56500.0  ...
# 396028      Gracon Services, Inc  10+ years       MORTGAGE     64000.0  ...
# 396029  Internal Revenue Service  10+ years           RENT     42996.0  ...
#
#        open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 396025      6.0     0.0    1990.0       34.3      23.0                    w
# 396026      6.0     0.0   43263.0       95.7       8.0                    f
# 396027     15.0     0.0   32704.0       66.9      23.0                    f
# 396028      9.0     0.0   15704.0       53.8      20.0                    f
# 396029      3.0     0.0    4292.0       91.3      19.0                    f
#
#        application_type  mort_acc  pub_rec_bankruptcies  \
# 396025       INDIVIDUAL       0.0                   0.0
# 396026       INDIVIDUAL       1.0                   0.0
# 396027       INDIVIDUAL       0.0                   0.0
# 396028       INDIVIDUAL       5.0                   0.0
# 396029       INDIVIDUAL       NaN                   0.0
#
#                                                   address
# 396025   12951 Williams Crossing\r\nJohnnyville, DC 30723
# 396026  0114 Fowler Field Suite 028\r\nRachelborough, ...
# 396027  953 Matthew Points Suite 414\r\nReedfort, NY 7...
# 396028  7843 Blake Freeway Apt. 229\r\nNew Michael, FL...
# 396029      787 Michelle Causeway\r\nBriannaton, AR 48052
#
# [5 rows x 27 columns]

# %% [markdown]
#  Criando um dicionario, para falar o que cada uma significa

# %%
colunas_traducao = {
    "loan_amnt": "valor_do_emprestimo",
    "term": "prazo_do_emprestimo_meses",
    "int_rate": "taxa_de_juros",
    "installment": "valor_da_parcela",
    "grade": "classificacao_de_risco",
    "sub_grade": "sub_classificacao_de_risco",
    "emp_title": "cargo_profissao",
    "emp_length": "tempo_de_emprego_anos",
    "home_ownership": "tipo_de_moradia",
    "annual_inc": "renda_anual",
    "verification_status": "status_de_verificacao_da_renda",
    "issue_d": "data_de_emissao_do_emprestimo",
    "loan_status": "status_do_emprestimo",
    "purpose": "finalidade_do_emprestimo",
    "title": "titulo_descricao_do_emprestimo",
    "dti": "relacao_divida_renda",
    "earliest_cr_line": "primeira_linha_de_credito",
    "open_acc": "contas_de_credito_abertas",
    "pub_rec": "registros_publicos_negativos",
    "revol_bal": "saldo_de_credito_rotativo",
    "revol_util": "utilizacao_do_credito_rotativo",
    "total_acc": "total_de_contas_de_credito",
    "initial_list_status": "status_inicial_de_listagem",
    "application_type": "tipo_de_aplicacao",
    "mort_acc": "contas_de_hipoteca",
    "pub_rec_bankruptcies": "registros_de_falencia",
    "address": "endereco"
}

# %% [markdown]
#  Renomeando as colunas

# %%
df = df.rename(columns = colunas_traducao)

# %% [markdown]
#  Observando se está certo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   valor_do_emprestimo             396030 non-null  float64
#  1   prazo_do_emprestimo_meses       396030 non-null  object
#  2   taxa_de_juros                   396030 non-null  float64
#  3   valor_da_parcela                396030 non-null  float64
#  4   classificacao_de_risco          396030 non-null  object
#  5   sub_classificacao_de_risco      396030 non-null  object
#  6   cargo_profissao                 373103 non-null  object
#  7   tempo_de_emprego_anos           377729 non-null  object
#  8   tipo_de_moradia                 396030 non-null  object
#  9   renda_anual                     396030 non-null  float64
#  10  status_de_verificacao_da_renda  396030 non-null  object
#  11  data_de_emissao_do_emprestimo   396030 non-null  object
#  12  status_do_emprestimo            396030 non-null  object
#  13  finalidade_do_emprestimo        396030 non-null  object
#  14  titulo_descricao_do_emprestimo  394274 non-null  object
#  15  relacao_divida_renda            396030 non-null  float64
#  16  primeira_linha_de_credito       396030 non-null  object
#  17  contas_de_credito_abertas       396030 non-null  float64
#  18  registros_publicos_negativos    396030 non-null  float64
#  19  saldo_de_credito_rotativo       396030 non-null  float64
#  20  utilizacao_do_credito_rotativo  395754 non-null  float64
#  21  total_de_contas_de_credito      396030 non-null  float64
#  22  status_inicial_de_listagem      396030 non-null  object
#  23  tipo_de_aplicacao               396030 non-null  object
#  24  contas_de_hipoteca              358235 non-null  float64
#  25  registros_de_falencia           395495 non-null  float64
#  26  endereco                        396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %% [markdown]
#  # 3_fase: Analisando e limpando dados

# %% [markdown]
#  *Nessa parte há o objetivo de tirar dados com pouca importancia, ver o que fazer com dados nulos, e organizar para tudo se transformar em dados númericos para ser lido pelo modelo*

# %% [markdown]
#  ### 3.1: Limpando os dados

# %% [markdown]
#  Tirando dados que pouca importância

# %%
df = df.drop(["titulo_descricao_do_emprestimo", "cargo_profissao", "status_inicial_de_listagem", "status_de_verificacao_da_renda"], axis=1)

# %% [markdown]
#  Observando se há dados vazios

# %%
df.isnull().sum()
# Out:
# valor_do_emprestimo                   0
# prazo_do_emprestimo_meses             0
# taxa_de_juros                         0
# valor_da_parcela                      0
# classificacao_de_risco                0
# sub_classificacao_de_risco            0
# tempo_de_emprego_anos             18301
# tipo_de_moradia                       0
# renda_anual                           0
# data_de_emissao_do_emprestimo         0
# status_do_emprestimo                  0
# finalidade_do_emprestimo              0
# relacao_divida_renda                  0
# primeira_linha_de_credito             0
# contas_de_credito_abertas             0
# registros_publicos_negativos          0
# saldo_de_credito_rotativo             0
# utilizacao_do_credito_rotativo      276
# total_de_contas_de_credito            0
# tipo_de_aplicacao                     0
# contas_de_hipoteca                37795
# registros_de_falencia               535
# endereco                              0
# dtype: int64

# %% [markdown]
#  olhando se o tipo dos dados são númericos para conseguir completar os dados com medianas, e não perder dados significativos

# %%
df["contas_de_hipoteca"].value_counts()
# Out:
# contas_de_hipoteca
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 26.0         2
# 32.0         2
# 31.0         2
# 23.0         2
# 34.0         1
# 28.0         1
# 30.0         1
# Name: count, dtype: int64

# %%
df["registros_de_falencia"].value_counts()
# Out:
# registros_de_falencia
# 0.0    350380
# 1.0     42790
# 2.0      1847
# 3.0       351
# 4.0        82
# 5.0        32
# 6.0         7
# 7.0         4
# 8.0         2
# Name: count, dtype: int64

# %%
df["utilizacao_do_credito_rotativo"].value_counts()
# Out:
# utilizacao_do_credito_rotativo
# 0.00      2213
# 53.00      752
# 60.00      739
# 61.00      734
# 55.00      730
#           ...
# 146.10       1
# 109.30       1
# 108.10       1
# 115.30       1
# 37.63        1
# Name: count, Length: 1226, dtype: int64

# %% [markdown]
#  Completando os dados que faltam nessas colunas com medianas considerando todos os valores que ja existem na sua coluna

# %%
df["utilizacao_do_credito_rotativo"] = df["utilizacao_do_credito_rotativo"].fillna(df["utilizacao_do_credito_rotativo"].median())
df["contas_de_hipoteca"] = df["contas_de_hipoteca"].fillna(df["contas_de_hipoteca"].median())
df["registros_de_falencia"] = df["registros_de_falencia"].fillna(df["registros_de_falencia"].median())

# %% [markdown]
#  Olhando os dados que faltam

# %%
df.isna().sum()
# Out:
# valor_do_emprestimo                   0
# prazo_do_emprestimo_meses             0
# taxa_de_juros                         0
# valor_da_parcela                      0
# classificacao_de_risco                0
# sub_classificacao_de_risco            0
# tempo_de_emprego_anos             18301
# tipo_de_moradia                       0
# renda_anual                           0
# data_de_emissao_do_emprestimo         0
# status_do_emprestimo                  0
# finalidade_do_emprestimo              0
# relacao_divida_renda                  0
# primeira_linha_de_credito             0
# contas_de_credito_abertas             0
# registros_publicos_negativos          0
# saldo_de_credito_rotativo             0
# utilizacao_do_credito_rotativo        0
# total_de_contas_de_credito            0
# tipo_de_aplicacao                     0
# contas_de_hipoteca                    0
# registros_de_falencia                 0
# endereco                              0
# dtype: int64

# %% [markdown]
#  Pegando a coluna que ainda tem dados faltando e aproveitando para mexer em outra que também é data

# %% [markdown]
#  Olhando como a coluna "tempo_de_emprego_anos" está organizada

# %%
df["tempo_de_emprego_anos"].value_counts()
# Out:
# tempo_de_emprego_anos
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: count, dtype: int64

# %% [markdown]
#  Criando um dicionario para transformar os dados dela em inteiros

# %%
tempo_emprego = {
"10+ years" : 10,
"2 years" : 2,
"< 1 year" : 0,
"3 years" : 3,
"5 years" : 5,
"1 year" : 1, 
"4 years" : 4, 
"6 years" : 6,
"7 years" : 7 , 
"8 years" : 8,
"9 years" : 9
}

# %% [markdown]
#  Olhando a outra coluna que também é data e classificada como objeto

# %%
df["prazo_do_emprestimo_meses"].value_counts()
# Out:
# prazo_do_emprestimo_meses
# 36 months    302005
# 60 months     94025
# Name: count, dtype: int64

# %% [markdown]
#  Uma para resolver passei uma função map que passa o dicionario e muda os dados pelas correções que estão no proprio dicionario, e em outro so tirei o "months" e mudei para "int" as respostas

# %%
df["tempo_de_emprego_anos"] = df["tempo_de_emprego_anos"].map(tempo_emprego)
df["prazo_do_emprestimo_meses"] = df["prazo_do_emprestimo_meses"].str.replace("months", "").astype(int)

# %% [markdown]
#  Olhando se está tudo certo

# %%
df["tempo_de_emprego_anos"].value_counts()
# Out:
# tempo_de_emprego_anos
# 10.0    126041
# 2.0      35827
# 0.0      31725
# 3.0      31665
# 5.0      26495
# 1.0      25882
# 4.0      23952
# 6.0      20841
# 7.0      20819
# 8.0      19168
# 9.0      15314
# Name: count, dtype: int64

# %%
df["prazo_do_emprestimo_meses"].value_counts()
# Out:
# prazo_do_emprestimo_meses
# 36    302005
# 60     94025
# Name: count, dtype: int64

# %% [markdown]
#  Agora completo os dados que estavam faltando na coluna "tempo_de_emprego_anos"

# %%
df["tempo_de_emprego_anos"] = df["tempo_de_emprego_anos"].replace(np.nan, df["tempo_de_emprego_anos"].median())

# %% [markdown]
#  Olho com "sample" para vir os dados aleatoriamente das linhas na coluna e vêr se deu certo

# %%
df["tempo_de_emprego_anos"].sample(20)
# Out:
# 138322     2.0
# 311990    10.0
# 273900     0.0
# 219258     8.0
# 69808     10.0
# 154902     6.0
# 153005    10.0
# 381594    10.0
# 56240      9.0
# 22090     10.0
# 111015    10.0
# 157310     1.0
# 81343     10.0
# 223566    10.0
# 332279     3.0
# 56088      9.0
# 367535    10.0
# 358054    10.0
# 352161    10.0
# 188091    10.0
# Name: tempo_de_emprego_anos, dtype: float64

# %% [markdown]
#  Tirando colunas que não sei qual foi o criterio para serem classificadas e meu modelo irá tenter prever essa resposta, então não faz sentido telas

# %%
df = df.drop(["classificacao_de_risco", "sub_classificacao_de_risco"], axis=1)

# %% [markdown]
#  Olhando se tem mais alguma colunas sem dados

# %%
df.isnull().sum()
# Out:
# valor_do_emprestimo               0
# prazo_do_emprestimo_meses         0
# taxa_de_juros                     0
# valor_da_parcela                  0
# tempo_de_emprego_anos             0
# tipo_de_moradia                   0
# renda_anual                       0
# data_de_emissao_do_emprestimo     0
# status_do_emprestimo              0
# finalidade_do_emprestimo          0
# relacao_divida_renda              0
# primeira_linha_de_credito         0
# contas_de_credito_abertas         0
# registros_publicos_negativos      0
# saldo_de_credito_rotativo         0
# utilizacao_do_credito_rotativo    0
# total_de_contas_de_credito        0
# tipo_de_aplicacao                 0
# contas_de_hipoteca                0
# registros_de_falencia             0
# endereco                          0
# dtype: int64

# %% [markdown]
#  Olhando o tipo das colunas agora, para pensar em o que fazer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   valor_do_emprestimo             396030 non-null  float64
#  1   prazo_do_emprestimo_meses       396030 non-null  int64
#  2   taxa_de_juros                   396030 non-null  float64
#  3   valor_da_parcela                396030 non-null  float64
#  4   tempo_de_emprego_anos           396030 non-null  float64
#  5   tipo_de_moradia                 396030 non-null  object
#  6   renda_anual                     396030 non-null  float64
#  7   data_de_emissao_do_emprestimo   396030 non-null  object
#  8   status_do_emprestimo            396030 non-null  object
#  9   finalidade_do_emprestimo        396030 non-null  object
#  10  relacao_divida_renda            396030 non-null  float64
#  11  primeira_linha_de_credito       396030 non-null  object
#  12  contas_de_credito_abertas       396030 non-null  float64
#  13  registros_publicos_negativos    396030 non-null  float64
#  14  saldo_de_credito_rotativo       396030 non-null  float64
#  15  utilizacao_do_credito_rotativo  396030 non-null  float64
#  16  total_de_contas_de_credito      396030 non-null  float64
#  17  tipo_de_aplicacao               396030 non-null  object
#  18  contas_de_hipoteca              396030 non-null  float64
#  19  registros_de_falencia           396030 non-null  float64
#  20  endereco                        396030 non-null  object
# dtypes: float64(13), int64(1), object(7)
# memory usage: 63.5+ MB

# %% [markdown]
#  Criando um laço que separa as colunas que são númericas e as que são textos para ver como está cada

# %%
colunas_numericas = []
colunas_texto = []
for i in df.columns.tolist():
  if df[i].dtype == "int64" or df[i].dtype == "float64":
     colunas_numericas.append(i)
  else:
     colunas_texto.append(i)

# %%
colunas_numericas
# Out:
# ['valor_do_emprestimo',
#  'prazo_do_emprestimo_meses',
#  'taxa_de_juros',
#  'valor_da_parcela',
#  'tempo_de_emprego_anos',
#  'renda_anual',
#  'relacao_divida_renda',
#  'contas_de_credito_abertas',
#  'registros_publicos_negativos',
#  'saldo_de_credito_rotativo',
#  'utilizacao_do_credito_rotativo',
#  'total_de_contas_de_credito',
#  'contas_de_hipoteca',
#  'registros_de_falencia']

# %%
colunas_texto
# Out:
# ['tipo_de_moradia',
#  'data_de_emissao_do_emprestimo',
#  'status_do_emprestimo',
#  'finalidade_do_emprestimo',
#  'primeira_linha_de_credito',
#  'tipo_de_aplicacao',
#  'endereco']

# %% [markdown]
#  Iremos tirar algumas coulunas que poderiam ser importantes, mas pesaria muito o processamento para esse teste, em um trabalho importante, com muito mais dados e um bom computador talvez valeria a pena

# %%
df = df.drop(["endereco", "data_de_emissao_do_emprestimo", "primeira_linha_de_credito"], axis=1)

# %% [markdown]
#  Fazendo o upload desse df agora limpo para ser usado no modelo, codificado e descodificado lá com o mesmo processo que sera usado aqui, mas em outro ambiente para ficar mais facil a decodificação

# %%
df.to_csv("dados_para_modelo.csv", sep=",", encoding="utf-8", index=False)

# %% [markdown]
#  ### 3.2: Codificando as colunas objetos para númericas

# %% [markdown]
#  Separando as colunas que são objetos, exceto a do "status_do_emprestimo" que a maquina irá tentar prever, criando um codificador que fará cada resposta diferente em cada coluna virar número e ainda deixando o nome da coluna que estava no df do pandas, depois de transformar junta com as colunas inteiras que ja tinham no df, fazendo um df_modelo

# %%
colunas_codificadas = df.select_dtypes(include="object").columns.drop("status_do_emprestimo")

codificador = OneHotEncoder(sparse_output=False, drop="first").set_output(transform="pandas")
df_codificado = codificador.fit_transform(df[colunas_codificadas])
df_modelo = pd.concat([df.drop(colunas_codificadas, axis=1), df_codificado], axis=1)

# %%
colunas_codificadas
# Out:
# Index(['tipo_de_moradia', 'finalidade_do_emprestimo', 'tipo_de_aplicacao'], dtype='object')

# %% [markdown]
#  Observando se está correto

# %%
df_modelo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 35 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   valor_do_emprestimo                          396030 non-null  float64
#  1   prazo_do_emprestimo_meses                    396030 non-null  int64
#  2   taxa_de_juros                                396030 non-null  float64
#  3   valor_da_parcela                             396030 non-null  float64
#  4   tempo_de_emprego_anos                        396030 non-null  float64
#  5   renda_anual                                  396030 non-null  float64
#  6   status_do_emprestimo                         396030 non-null  object
#  7   relacao_divida_renda                         396030 non-null  float64
#  8   contas_de_credito_abertas                    396030 non-null  float64
#  9   registros_publicos_negativos                 396030 non-null  float64
#  10  saldo_de_credito_rotativo                    396030 non-null  float64
#  11  utilizacao_do_credito_rotativo               396030 non-null  float64
#  12  total_de_contas_de_credito                   396030 non-null  float64
#  13  contas_de_hipoteca                           396030 non-null  float64
#  14  registros_de_falencia                        396030 non-null  float64
#  15  tipo_de_moradia_MORTGAGE                     396030 non-null  float64
#  16  tipo_de_moradia_NONE                         396030 non-null  float64
#  17  tipo_de_moradia_OTHER                        396030 non-null  float64
#  18  tipo_de_moradia_OWN                          396030 non-null  float64
#  19  tipo_de_moradia_RENT                         396030 non-null  float64
#  20  finalidade_do_emprestimo_credit_card         396030 non-null  float64
#  21  finalidade_do_emprestimo_debt_consolidation  396030 non-null  float64
#  22  finalidade_do_emprestimo_educational         396030 non-null  float64
#  23  finalidade_do_emprestimo_home_improvement    396030 non-null  float64
#  24  finalidade_do_emprestimo_house               396030 non-null  float64
#  25  finalidade_do_emprestimo_major_purchase      396030 non-null  float64
#  26  finalidade_do_emprestimo_medical             396030 non-null  float64
#  27  finalidade_do_emprestimo_moving              396030 non-null  float64
#  28  finalidade_do_emprestimo_other               396030 non-null  float64
#  29  finalidade_do_emprestimo_renewable_energy    396030 non-null  float64
#  30  finalidade_do_emprestimo_small_business      396030 non-null  float64
#  31  finalidade_do_emprestimo_vacation            396030 non-null  float64
#  32  finalidade_do_emprestimo_wedding             396030 non-null  float64
#  33  tipo_de_aplicacao_INDIVIDUAL                 396030 non-null  float64
#  34  tipo_de_aplicacao_JOINT                      396030 non-null  float64
# dtypes: float64(33), int64(1), object(1)
# memory usage: 105.8+ MB

# %% [markdown]
#  Transformando separadamente o "status_do_emprestimo"

# %%
df["status_do_emprestimo"].value_counts()
# Out:
# status_do_emprestimo
# Fully Paid     318357
# Charged Off     77673
# Name: count, dtype: int64

# %%
status_emprestimo = {
"Fully Paid" : 1,
"Charged Off" : 0
}

# %%
df_modelo["status_do_emprestimo"] = df_modelo["status_do_emprestimo"].map(status_emprestimo)

# %% [markdown]
#  Deixando em primeiro só para não ficar caçando no gráfico de correlação

# %%
df_modelo.set_index("status_do_emprestimo", inplace=True)

# %%
df_modelo.reset_index(inplace=True)

# %%
df_modelo.sample(20)
# Out:
#         status_do_emprestimo  valor_do_emprestimo  prazo_do_emprestimo_meses  \
# 108567                     1               9000.0                         36
# 229773                     0               3000.0                         36
# 211364                     1              20000.0                         36
# 197297                     1              27500.0                         60
# 391335                     1              20000.0                         36
# 185227                     1              25600.0                         60
# 241285                     1               9450.0                         36
# 121889                     1              12000.0                         36
# 128225                     0              11000.0                         36
# 382657                     1              10000.0                         60
# 302989                     0              12000.0                         36
# 186581                     0              18500.0                         60
# 249342                     1               5000.0                         36
# 70910                      0              14375.0                         60
# 95981                      0              35000.0                         60
# 292290                     1               4950.0                         36
# 248227                     1              17000.0                         60
# 214550                     1               3000.0                         36
# 204366                     1              11175.0                         36
# 26003                      0               3000.0                         36
#
#         taxa_de_juros  valor_da_parcela  tempo_de_emprego_anos  renda_anual  \
# 108567           9.99            290.37                    2.0      70000.0
# 229773          21.49            113.79                    1.0      72700.0
# 211364          17.57            718.75                   10.0      70000.0
# 197297          16.29            673.00                    0.0     111000.0
# 391335          10.99            654.68                    6.0     150000.0
# 185227           9.99            543.80                   10.0     124000.0
# 241285          18.49            343.97                    2.0      35000.0
# 121889          12.85            403.47                    7.0      96000.0
# 128225           7.49            342.12                    4.0      60000.0
# 382657          18.25            255.30                    8.0     250000.0
# 302989           9.67            385.35                   10.0      55000.0
# 186581          16.99            459.68                    8.0      65000.0
# 249342           5.32            150.58                    6.0      28000.0
# 70910           21.99            396.95                    1.0      37000.0
# 95981           18.55            899.28                    0.0     150000.0
# 292290          14.49            170.36                   10.0      51000.0
# 248227          15.61            409.90                    1.0      40000.0
# 214550          13.33            101.56                   10.0      65000.0
# 204366          14.99            387.34                    1.0      35000.0
# 26003           14.33            103.02                    8.0     115000.0
#
#         relacao_divida_renda  contas_de_credito_abertas  \
# 108567                  8.04                        8.0
# 229773                  6.69                        6.0
# 211364                 11.25                       16.0
# 197297                 22.27                       22.0
# 391335                 23.02                       17.0
# 185227                 25.57                       19.0
# 241285                 19.71                        7.0
# 121889                  7.11                        8.0
# 128225                 13.38                       13.0
# 382657                  1.95                        7.0
# 302989                 26.12                       35.0
# 186581                 16.99                        6.0
# 249342                  2.70                       14.0
# 70910                  38.18                       12.0
# 95981                  21.52                       21.0
# 292290                 13.60                        6.0
# 248227                 28.68                       14.0
# 214550                  9.56                       23.0
# 204366                 17.56                       13.0
# 26003                   7.12                        5.0
#
#         registros_publicos_negativos  ...  \
# 108567                           0.0  ...
# 229773                           0.0  ...
# 211364                           0.0  ...
# 197297                           0.0  ...
# 391335                           0.0  ...
# 185227                           0.0  ...
# 241285                           0.0  ...
# 121889                           0.0  ...
# 128225                           1.0  ...
# 382657                           0.0  ...
# 302989                           0.0  ...
# 186581                           0.0  ...
# 249342                           0.0  ...
# 70910                            0.0  ...
# 95981                            0.0  ...
# 292290                           0.0  ...
# 248227                           0.0  ...
# 214550                           1.0  ...
# 204366                           0.0  ...
# 26003                            0.0  ...
#
#         finalidade_do_emprestimo_major_purchase  \
# 108567                                      1.0
# 229773                                      0.0
# 211364                                      0.0
# 197297                                      0.0
# 391335                                      0.0
# 185227                                      0.0
# 241285                                      0.0
# 121889                                      1.0
# 128225                                      0.0
# 382657                                      0.0
# 302989                                      0.0
# 186581                                      0.0
# 249342                                      0.0
# 70910                                       0.0
# 95981                                       0.0
# 292290                                      0.0
# 248227                                      0.0
# 214550                                      0.0
# 204366                                      1.0
# 26003                                       0.0
#
#         finalidade_do_emprestimo_medical  finalidade_do_emprestimo_moving  \
# 108567                               0.0                              0.0
# 229773                               0.0                              0.0
# 211364                               0.0                              0.0
# 197297                               0.0                              0.0
# 391335                               0.0                              0.0
# 185227                               0.0                              0.0
# 241285                               0.0                              0.0
# 121889                               0.0                              0.0
# 128225                               0.0                              0.0
# 382657                               0.0                              0.0
# 302989                               0.0                              0.0
# 186581                               0.0                              0.0
# 249342                               0.0                              0.0
# 70910                                0.0                              0.0
# 95981                                0.0                              0.0
# 292290                               0.0                              0.0
# 248227                               0.0                              0.0
# 214550                               0.0                              0.0
# 204366                               0.0                              0.0
# 26003                                0.0                              0.0
#
#         finalidade_do_emprestimo_other  \
# 108567                             0.0
# 229773                             0.0
# 211364                             0.0
# 197297                             0.0
# 391335                             0.0
# 185227                             0.0
# 241285                             1.0
# 121889                             0.0
# 128225                             0.0
# 382657                             0.0
# 302989                             0.0
# 186581                             0.0
# 249342                             0.0
# 70910                              0.0
# 95981                              0.0
# 292290                             0.0
# 248227                             0.0
# 214550                             0.0
# 204366                             0.0
# 26003                              0.0
#
#         finalidade_do_emprestimo_renewable_energy  \
# 108567                                        0.0
# 229773                                        0.0
# 211364                                        0.0
# 197297                                        0.0
# 391335                                        0.0
# 185227                                        0.0
# 241285                                        0.0
# 121889                                        0.0
# 128225                                        0.0
# 382657                                        0.0
# 302989                                        0.0
# 186581                                        0.0
# 249342                                        0.0
# 70910                                         0.0
# 95981                                         0.0
# 292290                                        0.0
# 248227                                        0.0
# 214550                                        0.0
# 204366                                        0.0
# 26003                                         0.0
#
#         finalidade_do_emprestimo_small_business  \
# 108567                                      0.0
# 229773                                      0.0
# 211364                                      0.0
# 197297                                      0.0
# 391335                                      0.0
# 185227                                      0.0
# 241285                                      0.0
# 121889                                      0.0
# 128225                                      0.0
# 382657                                      0.0
# 302989                                      0.0
# 186581                                      0.0
# 249342                                      0.0
# 70910                                       0.0
# 95981                                       0.0
# 292290                                      0.0
# 248227                                      0.0
# 214550                                      0.0
# 204366                                      0.0
# 26003                                       0.0
#
#         finalidade_do_emprestimo_vacation  finalidade_do_emprestimo_wedding  \
# 108567                                0.0                               0.0
# 229773                                1.0                               0.0
# 211364                                0.0                               0.0
# 197297                                0.0                               0.0
# 391335                                0.0                               0.0
# 185227                                0.0                               0.0
# 241285                                0.0                               0.0
# 121889                                0.0                               0.0
# 128225                                0.0                               0.0
# 382657                                0.0                               0.0
# 302989                                0.0                               0.0
# 186581                                0.0                               0.0
# 249342                                0.0                               0.0
# 70910                                 0.0                               0.0
# 95981                                 0.0                               0.0
# 292290                                0.0                               0.0
# 248227                                0.0                               0.0
# 214550                                0.0                               0.0
# 204366                                0.0                               0.0
# 26003                                 0.0                               0.0
#
#         tipo_de_aplicacao_INDIVIDUAL  tipo_de_aplicacao_JOINT
# 108567                           1.0                      0.0
# 229773                           1.0                      0.0
# 211364                           1.0                      0.0
# 197297                           1.0                      0.0
# 391335                           1.0                      0.0
# 185227                           1.0                      0.0
# 241285                           1.0                      0.0
# 121889                           1.0                      0.0
# 128225                           1.0                      0.0
# 382657                           1.0                      0.0
# 302989                           1.0                      0.0
# 186581                           1.0                      0.0
# 249342                           1.0                      0.0
# 70910                            1.0                      0.0
# 95981                            1.0                      0.0
# 292290                           1.0                      0.0
# 248227                           1.0                      0.0
# 214550                           1.0                      0.0
# 204366                           1.0                      0.0
# 26003                            1.0                      0.0
#
# [20 rows x 35 columns]

# %% [markdown]
#  # 4_fase: Criando gŕaficos e analisanod

# %% [markdown]
#  ### 4.1 Gráfico de correlação

# %%
corr = df_modelo.corr()

grafico_calor = plt.figure(figsize=(30, 8))

sns.heatmap(corr, annot=True, cmap= "coolwarm")

grafico_calor.show
# Out:
# <bound method Figure.show of <Figure size 3000x800 with 2 Axes>>

# %% [markdown]
#  Aqui pode ser visto que não existe nenhum separadamente que tem muita relação com o "status_do_emprestimo", apenas um pouco a "taxa_de_juros"
